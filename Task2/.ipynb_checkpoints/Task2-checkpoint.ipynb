# %%
import pandas as pd

# %%
df = pd.read_csv('smartphones_data.csv')

# %%
print(f"Shape: {df.shape[0]} rows, {df.shape[1]} columns")
# Out:
# Shape: 3260 rows, 20 columns

# %%
print("\nColumn Types:")
print(df.dtypes)
# Out:
# Column Types:
# brand_name               object
# Name                     object
# Price                     int64
# RAM                     float64
# OS                       object
# storage                 float64
# Battery_cap               int64
# has_fast_charging        object
# has_fingerprints         object
# has_nfc                  object
# has_5g                   object
# processor_brand          object
# num_core                float64
# primery_rear_camera     float64
# Num_Rear_Cameras          int64
# primery_front_camera    float64
# num_front_camera          int64
# display_size(inch)      float64
# refresh_rate(hz)        float64
# display_types            object
# dtype: object

# %%
print("\nSample Data:")
print(df.head(3))
# Out:
# Sample Data:
#   brand_name                Name  Price  RAM       OS  storage  Battery_cap  \
# 0       vivo            vivo v50  34999  8.0  android    128.0         6000
# 1     realme       realme p3 pro  21999  8.0  android    128.0         6000
# 2     realme  realme 14 pro plus  27999  8.0  android    128.0         6000
#
#   has_fast_charging has_fingerprints has_nfc has_5g processor_brand  num_core  \
# 0               Yes              Yes      No    Yes      snapdragon       8.0
# 1               Yes              Yes      No    Yes      snapdragon       8.0
# 2               Yes              Yes      No    Yes      snapdragon       8.0
#
#    primery_rear_camera  Num_Rear_Cameras  primery_front_camera  \
# 0                 50.0                 2                  50.0
# 1                 50.0                 2                  16.0
# 2                 50.0                 3                  32.0
#
#    num_front_camera  display_size(inch)  refresh_rate(hz)   display_types
# 0                 1                6.77             120.0  amoled display
# 1                 1                6.83             120.0  amoled display
# 2                 1                6.83             120.0    oled display

# %%
missing = df.isnull().sum()
print(missing[missing > 0] if missing.any() else "No missing values.")
# Out:
# has_fingerprints     726
# has_nfc              726
# has_5g               726
# num_core             175
# refresh_rate(hz)    1731
# dtype: int64

# %%
binary_cols = ['has_fast_charging', 'has_fingerprints', 'has_5g', 'has_nfc']
for col in binary_cols:
    df[col] = df[col].fillna('No')


df['num_core'] = df['num_core'].fillna(df['num_core'].median())
df['refresh_rate(hz)'] = df['refresh_rate(hz)'].fillna(df['refresh_rate(hz)'].mode()[0])

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.isnull(), cbar=False, cmap='viridis')
plt.show()

# %%
df.describe(include='all')
# Out:
#        brand_name      Name          Price          RAM       OS      storage  \
# count        3260      3260    3260.000000  3260.000000     3260  3260.000000
# unique         33      3260            NaN          NaN        3          NaN
# top       samsung  vivo v50            NaN          NaN  android          NaN
# freq          315         1            NaN          NaN     3130          NaN
# mean          NaN       NaN   20181.384356     5.065874      NaN   112.040893
# std           NaN       NaN   24145.388368     3.256896      NaN   126.893532
# min           NaN       NaN    2500.000000     0.250000      NaN     0.310000
# 25%           NaN       NaN    7490.000000     3.000000      NaN    32.000000
# 50%           NaN       NaN   11999.000000     4.000000      NaN    64.000000
# 75%           NaN       NaN   21999.000000     8.000000      NaN   128.000000
# max           NaN       NaN  200999.000000    24.000000      NaN  1024.000000
#
#          Battery_cap has_fast_charging has_fingerprints has_nfc has_5g  \
# count    3260.000000              3260             3260    3260   3260
# unique           NaN                 2                2       2      2
# top              NaN                No              Yes      No     No
# freq             NaN              1717             2391    2425   2257
# mean     4163.485583               NaN              NaN     NaN    NaN
# std      1312.404904               NaN              NaN     NaN    NaN
# min      1100.000000               NaN              NaN     NaN    NaN
# 25%      3007.500000               NaN              NaN     NaN    NaN
# 50%      4500.000000               NaN              NaN     NaN    NaN
# 75%      5000.000000               NaN              NaN     NaN    NaN
# max     22000.000000               NaN              NaN     NaN    NaN
#
#        processor_brand     num_core  primery_rear_camera  Num_Rear_Cameras  \
# count             3260  3260.000000          3260.000000       3260.000000
# unique              15          NaN                  NaN               NaN
# top           mediatek          NaN                  NaN               NaN
# freq              1384          NaN                  NaN               NaN
# mean               NaN     7.138037            32.655828          2.076994
# std                NaN     1.649559            29.397695          0.990856
# min                NaN     1.000000             0.300000          1.000000
# 25%                NaN     8.000000            12.000000          1.000000
# 50%                NaN     8.000000            16.000000          2.000000
# 75%                NaN     8.000000            50.000000          3.000000
# max                NaN    10.000000           200.000000          5.000000
#
#         primery_front_camera  num_front_camera  display_size(inch)  \
# count            3260.000000       3260.000000         3260.000000
# unique                   NaN               NaN                 NaN
# top                      NaN               NaN                 NaN
# freq                     NaN               NaN                 NaN
# mean               12.555767          1.026994            6.097110
# std                10.564795          0.162090            0.741478
# min                 0.300000          1.000000            2.400000
# 25%                 5.000000          1.000000            5.500000
# 50%                 8.000000          1.000000            6.455000
# 75%                16.000000          1.000000            6.670000
# max                60.000000          2.000000            8.030000
#
#         refresh_rate(hz) display_types
# count        3260.000000          3260
# unique               NaN             5
# top                  NaN   lcd display
# freq                 NaN          2010
# mean          110.795706           NaN
# std            19.675115           NaN
# min            60.000000           NaN
# 25%           120.000000           NaN
# 50%           120.000000           NaN
# 75%           120.000000           NaN
# max           165.000000           NaN

# %%
correlation = df.corr(numeric_only=True)
sns.heatmap(correlation, annot=True, cmap='coolwarm')
plt.title("Feature Correlation")
plt.show()

# %%
df.groupby('brand_name')['Price'].mean().sort_values(ascending=False).plot(kind='bar')
plt.title("Average Price by Brand")
plt.show()
